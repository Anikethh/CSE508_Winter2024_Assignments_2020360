# %%
import os
import nltk
import string

nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [token for token in tokens if token not in string.punctuation]
    tokens = [token for token in tokens if token.strip() != '']
    return tokens

def create_inverted_index(dataset_path):
    inverted_index = {}
    for filename in os.listdir(dataset_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(dataset_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()
                tokens = preprocess_text(text)
                for position, term in enumerate(tokens):
                    if term not in inverted_index:
                        inverted_index[term] = []
                    if filename not in inverted_index[term]:
                        inverted_index[term].append(filename)
    return inverted_index

def save_inverted_index(inverted_index, output_file):
    with open(output_file, 'w', encoding='utf-8') as file:
        for term, documents in inverted_index.items():
            file.write(term + ":" + ",".join(documents) + "\n")

dataset_path = "text_files_preprocessed"
output_file = "inverted_index.txt"

inverted_index = create_inverted_index(dataset_path)

save_inverted_index(inverted_index, output_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pickle

def save_inverted_index_as_pickle(inverted_index, output_file):
    with open(output_file, 'wb') as file:
        pickle.dump(inverted_index, file)

save_inverted_index_as_pickle(inverted_index, 'inverted_index.pickle')

# %%
import pickle

def load_inverted_index(pickle_file):
    with open(pickle_file, 'rb') as file:
        inverted_index = pickle.load(file)
    return inverted_index

def and_operation(inverted_index, term1, term2):
    if term1 not in inverted_index or term2 not in inverted_index:
        return []
    return list(set(inverted_index[term1]) & set(inverted_index[term2]))

def or_operation(inverted_index, term1, term2):
    documents = set()
    if term1 in inverted_index:
        documents.update(inverted_index[term1])
    if term2 in inverted_index:
        documents.update(inverted_index[term2])
    return list(documents)

def and_not_operation(inverted_index, term1, term2):
    if term1 not in inverted_index or term2 not in inverted_index:
        return []
    return list(set(inverted_index[term1]) - set(inverted_index[term2]))

def or_not_operation(inverted_index, term1, term2):
    documents = set(inverted_index.get(term1, []))
    excluded_documents = set(inverted_index.get(term2, []))
    return list(documents - excluded_documents)

if __name__ == "__main__":
    inverted_index = load_inverted_index("inverted_index.pickle")

    term1 = "great"
    term2 = "stability"

    # T1 AND T2
    print("T1 AND T2:", and_operation(inverted_index, term1, term2))

    # T1 OR T2
    print("T1 OR T2:", or_operation(inverted_index, term1, term2))

    # T1 AND NOT T2
    print("T1 AND NOT T2:", and_not_operation(inverted_index, term1, term2))

    # T1 OR NOT T2
    print("T1 OR NOT T2:", or_not_operation(inverted_index, term1, term2))
# Out:
# T1 AND T2: ['file382.txt', 'file1.txt', 'file115.txt']
# T1 OR T2: ['file62.txt', 'file999.txt', 'file152.txt', 'file433.txt', 'file939.txt', 'file553.txt', 'file810.txt', 'file78.txt', 'file657.txt', 'file696.txt', 'file759.txt', 'file251.txt', 'file439.txt', 'file854.txt', 'file861.txt', 'file934.txt', 'file835.txt', 'file593.txt', 'file273.txt', 'file806.txt', 'file4.txt', 'file573.txt', 'file96.txt', 'file28.txt', 'file148.txt', 'file476.txt', 'file811.txt', 'file467.txt', 'file26.txt', 'file99.txt', 'file699.txt', 'file91.txt', 'file428.txt', 'file879.txt', 'file457.txt', 'file183.txt', 'file330.txt', 'file466.txt', 'file13.txt', 'file857.txt', 'file491.txt', 'file238.txt', 'file435.txt', 'file684.txt', 'file64.txt', 'file740.txt', 'file546.txt', 'file101.txt', 'file516.txt', 'file618.txt', 'file465.txt', 'file444.txt', 'file518.txt', 'file639.txt', 'file108.txt', 'file539.txt', 'file781.txt', 'file708.txt', 'file704.txt', 'file611.txt', 'file956.txt', 'file988.txt', 'file882.txt', 'file393.txt', 'file100.txt', 'file561.txt', 'file731.txt', 'file920.txt', 'file749.txt', 'file751.txt', 'file198.txt', 'file977.txt', 'file522.txt', 'file21.txt', 'file455.txt', 'file481.txt', 'file979.txt', 'file320.txt', 'file972.txt', 'file140.txt', 'file689.txt', 'file463.txt', 'file761.txt', 'file215.txt', 'file371.txt', 'file375.txt', 'file953.txt', 'file521.txt', 'file122.txt', 'file894.txt', 'file38.txt', 'file548.txt', 'file549.txt', 'file600.txt', 'file843.txt', 'file514.txt', 'file240.txt', 'file567.txt', 'file192.txt', 'file260.txt', 'file692.txt', 'file727.txt', 'file188.txt', 'file374.txt', 'file804.txt', 'file115.txt', 'file615.txt', 'file534.txt', 'file597.txt', 'file765.txt', 'file503.txt', 'file606.txt', 'file940.txt', 'file993.txt', 'file89.txt', 'file542.txt', 'file176.txt', 'file452.txt', 'file304.txt', 'file410.txt', 'file560.txt', 'file36.txt', 'file523.txt', 'file309.txt', 'file760.txt', 'file966.txt', 'file333.txt', 'file337.txt', 'file190.txt', 'file477.txt', 'file276.txt', 'file389.txt', 'file206.txt', 'file197.txt', 'file336.txt', 'file686.txt', 'file423.txt', 'file396.txt', 'file404.txt', 'file543.txt', 'file124.txt', 'file71.txt', 'file131.txt', 'file48.txt', 'file329.txt', 'file860.txt', 'file578.txt', 'file856.txt', 'file729.txt', 'file888.txt', 'file723.txt', 'file788.txt', 'file380.txt', 'file412.txt', 'file497.txt', 'file627.txt', 'file129.txt', 'file254.txt', 'file506.txt', 'file644.txt', 'file799.txt', 'file456.txt', 'file973.txt', 'file450.txt', 'file557.txt', 'file504.txt', 'file874.txt', 'file581.txt', 'file535.txt', 'file626.txt', 'file479.txt', 'file394.txt', 'file976.txt', 'file220.txt', 'file257.txt', 'file256.txt', 'file277.txt', 'file67.txt', 'file929.txt', 'file576.txt', 'file551.txt', 'file364.txt', 'file517.txt', 'file544.txt', 'file105.txt', 'file424.txt', 'file84.txt', 'file205.txt', 'file127.txt', 'file748.txt', 'file420.txt', 'file98.txt', 'file601.txt', 'file509.txt', 'file216.txt', 'file850.txt', 'file156.txt', 'file719.txt', 'file946.txt', 'file637.txt', 'file69.txt', 'file505.txt', 'file413.txt', 'file752.txt', 'file5.txt', 'file899.txt', 'file965.txt', 'file283.txt', 'file997.txt', 'file343.txt', 'file712.txt', 'file767.txt', 'file664.txt', 'file360.txt', 'file891.txt', 'file271.txt', 'file825.txt', 'file235.txt', 'file849.txt', 'file568.txt', 'file147.txt', 'file907.txt', 'file791.txt', 'file30.txt', 'file2.txt', 'file531.txt', 'file945.txt', 'file681.txt', 'file83.txt', 'file132.txt', 'file376.txt', 'file577.txt', 'file512.txt', 'file234.txt', 'file852.txt', 'file1.txt', 'file897.txt', 'file65.txt', 'file776.txt', 'file820.txt', 'file137.txt', 'file604.txt', 'file922.txt', 'file836.txt', 'file872.txt', 'file580.txt', 'file598.txt', 'file625.txt', 'file167.txt', 'file286.txt', 'file621.txt', 'file931.txt', 'file278.txt', 'file426.txt', 'file890.txt', 'file119.txt', 'file400.txt', 'file429.txt', 'file214.txt', 'file906.txt', 'file345.txt', 'file771.txt', 'file334.txt', 'file715.txt', 'file733.txt', 'file269.txt', 'file102.txt', 'file794.txt', ...
# T1 AND NOT T2: ['file62.txt', 'file535.txt', 'file999.txt', 'file152.txt', 'file433.txt', 'file939.txt', 'file626.txt', 'file479.txt', 'file394.txt', 'file976.txt', 'file220.txt', 'file257.txt', 'file553.txt', 'file256.txt', 'file810.txt', 'file277.txt', 'file78.txt', 'file657.txt', 'file67.txt', 'file929.txt', 'file576.txt', 'file696.txt', 'file551.txt', 'file364.txt', 'file251.txt', 'file517.txt', 'file544.txt', 'file105.txt', 'file439.txt', 'file424.txt', 'file854.txt', 'file84.txt', 'file205.txt', 'file127.txt', 'file861.txt', 'file934.txt', 'file835.txt', 'file593.txt', 'file273.txt', 'file748.txt', 'file420.txt', 'file806.txt', 'file98.txt', 'file601.txt', 'file4.txt', 'file509.txt', 'file216.txt', 'file573.txt', 'file96.txt', 'file28.txt', 'file850.txt', 'file148.txt', 'file476.txt', 'file156.txt', 'file811.txt', 'file719.txt', 'file946.txt', 'file637.txt', 'file467.txt', 'file69.txt', 'file505.txt', 'file413.txt', 'file752.txt', 'file26.txt', 'file99.txt', 'file5.txt', 'file699.txt', 'file91.txt', 'file899.txt', 'file428.txt', 'file879.txt', 'file965.txt', 'file283.txt', 'file457.txt', 'file183.txt', 'file330.txt', 'file466.txt', 'file997.txt', 'file343.txt', 'file13.txt', 'file857.txt', 'file491.txt', 'file238.txt', 'file435.txt', 'file712.txt', 'file684.txt', 'file64.txt', 'file740.txt', 'file546.txt', 'file101.txt', 'file767.txt', 'file516.txt', 'file618.txt', 'file664.txt', 'file360.txt', 'file465.txt', 'file444.txt', 'file518.txt', 'file891.txt', 'file639.txt', 'file271.txt', 'file825.txt', 'file235.txt', 'file108.txt', 'file539.txt', 'file849.txt', 'file781.txt', 'file708.txt', 'file568.txt', 'file147.txt', 'file907.txt', 'file704.txt', 'file791.txt', 'file30.txt', 'file2.txt', 'file611.txt', 'file956.txt', 'file531.txt', 'file945.txt', 'file988.txt', 'file681.txt', 'file83.txt', 'file882.txt', 'file393.txt', 'file132.txt', 'file376.txt', 'file100.txt', 'file577.txt', 'file512.txt', 'file561.txt', 'file731.txt', 'file920.txt', 'file234.txt', 'file852.txt', 'file749.txt', 'file751.txt', 'file897.txt', 'file198.txt', 'file977.txt', 'file65.txt', 'file776.txt', 'file522.txt', 'file21.txt', 'file455.txt', 'file481.txt', 'file820.txt', 'file137.txt', 'file604.txt', 'file979.txt', 'file320.txt', 'file922.txt', 'file836.txt', 'file872.txt', 'file972.txt', 'file580.txt', 'file598.txt', 'file625.txt', 'file167.txt', 'file286.txt', 'file140.txt', 'file689.txt', 'file621.txt', 'file931.txt', 'file463.txt', 'file761.txt', 'file215.txt', 'file371.txt', 'file375.txt', 'file953.txt', 'file278.txt', 'file426.txt', 'file890.txt', 'file122.txt', 'file119.txt', 'file400.txt', 'file894.txt', 'file38.txt', 'file548.txt', 'file429.txt', 'file549.txt', 'file214.txt', 'file906.txt', 'file345.txt', 'file600.txt', 'file843.txt', 'file514.txt', 'file771.txt', 'file240.txt', 'file334.txt', 'file715.txt', 'file567.txt', 'file733.txt', 'file269.txt', 'file102.txt', 'file192.txt', 'file260.txt', 'file692.txt', 'file727.txt', 'file188.txt', 'file374.txt', 'file794.txt', 'file301.txt', 'file668.txt', 'file274.txt', 'file804.txt', 'file252.txt', 'file615.txt', 'file951.txt', 'file103.txt', 'file534.txt', 'file599.txt', 'file230.txt', 'file597.txt', 'file765.txt', 'file408.txt', 'file503.txt', 'file44.txt', 'file865.txt', 'file606.txt', 'file940.txt', 'file993.txt', 'file89.txt', 'file542.txt', 'file176.txt', 'file452.txt', 'file515.txt', 'file304.txt', 'file410.txt', 'file560.txt', 'file8.txt', 'file36.txt', 'file523.txt', 'file309.txt', 'file187.txt', 'file306.txt', 'file104.txt', 'file121.txt', 'file760.txt', 'file966.txt', 'file349.txt', 'file363.txt', 'file333.txt', 'file656.txt', 'file337.txt', 'file190.txt', 'file347.txt', 'file407.txt', 'file477.txt', 'file276.txt', 'file389.txt', 'file390.txt', 'file206.txt', 'file425.txt', 'file197.txt', 'file139.txt', 'file336.txt', 'file686.txt', 'file423.txt', 'file396.txt', 'file498.txt', 'file404.txt', 'file543.txt', 'file734.txt', 'file362.txt', 'file241.txt', 'file124.txt', 'file789.txt', 'file71. ...
# T1 OR NOT T2: ['file62.txt', 'file535.txt', 'file999.txt', 'file152.txt', 'file433.txt', 'file939.txt', 'file626.txt', 'file479.txt', 'file394.txt', 'file976.txt', 'file220.txt', 'file257.txt', 'file553.txt', 'file256.txt', 'file810.txt', 'file277.txt', 'file78.txt', 'file657.txt', 'file67.txt', 'file929.txt', 'file576.txt', 'file696.txt', 'file551.txt', 'file364.txt', 'file251.txt', 'file517.txt', 'file544.txt', 'file105.txt', 'file439.txt', 'file424.txt', 'file854.txt', 'file84.txt', 'file205.txt', 'file127.txt', 'file861.txt', 'file934.txt', 'file835.txt', 'file593.txt', 'file273.txt', 'file748.txt', 'file420.txt', 'file806.txt', 'file98.txt', 'file601.txt', 'file4.txt', 'file509.txt', 'file216.txt', 'file573.txt', 'file96.txt', 'file28.txt', 'file850.txt', 'file148.txt', 'file476.txt', 'file156.txt', 'file811.txt', 'file719.txt', 'file946.txt', 'file637.txt', 'file467.txt', 'file69.txt', 'file505.txt', 'file413.txt', 'file752.txt', 'file26.txt', 'file99.txt', 'file5.txt', 'file699.txt', 'file91.txt', 'file899.txt', 'file428.txt', 'file879.txt', 'file965.txt', 'file283.txt', 'file457.txt', 'file183.txt', 'file330.txt', 'file466.txt', 'file997.txt', 'file343.txt', 'file13.txt', 'file857.txt', 'file491.txt', 'file238.txt', 'file435.txt', 'file712.txt', 'file684.txt', 'file64.txt', 'file740.txt', 'file546.txt', 'file101.txt', 'file767.txt', 'file516.txt', 'file618.txt', 'file664.txt', 'file360.txt', 'file465.txt', 'file444.txt', 'file518.txt', 'file891.txt', 'file639.txt', 'file271.txt', 'file825.txt', 'file235.txt', 'file108.txt', 'file539.txt', 'file849.txt', 'file781.txt', 'file708.txt', 'file568.txt', 'file147.txt', 'file907.txt', 'file704.txt', 'file791.txt', 'file30.txt', 'file2.txt', 'file611.txt', 'file956.txt', 'file531.txt', 'file945.txt', 'file988.txt', 'file681.txt', 'file83.txt', 'file882.txt', 'file393.txt', 'file132.txt', 'file376.txt', 'file100.txt', 'file577.txt', 'file512.txt', 'file561.txt', 'file731.txt', 'file920.txt', 'file234.txt', 'file852.txt', 'file749.txt', 'file751.txt', 'file897.txt', 'file198.txt', 'file977.txt', 'file65.txt', 'file776.txt', 'file522.txt', 'file21.txt', 'file455.txt', 'file481.txt', 'file820.txt', 'file137.txt', 'file604.txt', 'file979.txt', 'file320.txt', 'file922.txt', 'file836.txt', 'file872.txt', 'file972.txt', 'file580.txt', 'file598.txt', 'file625.txt', 'file167.txt', 'file286.txt', 'file140.txt', 'file689.txt', 'file621.txt', 'file931.txt', 'file463.txt', 'file761.txt', 'file215.txt', 'file371.txt', 'file375.txt', 'file953.txt', 'file278.txt', 'file426.txt', 'file890.txt', 'file122.txt', 'file119.txt', 'file400.txt', 'file894.txt', 'file38.txt', 'file548.txt', 'file429.txt', 'file549.txt', 'file214.txt', 'file906.txt', 'file345.txt', 'file600.txt', 'file843.txt', 'file514.txt', 'file771.txt', 'file240.txt', 'file334.txt', 'file715.txt', 'file567.txt', 'file733.txt', 'file269.txt', 'file102.txt', 'file192.txt', 'file260.txt', 'file692.txt', 'file727.txt', 'file188.txt', 'file374.txt', 'file794.txt', 'file301.txt', 'file668.txt', 'file274.txt', 'file804.txt', 'file252.txt', 'file615.txt', 'file951.txt', 'file103.txt', 'file534.txt', 'file599.txt', 'file230.txt', 'file597.txt', 'file765.txt', 'file408.txt', 'file503.txt', 'file44.txt', 'file865.txt', 'file606.txt', 'file940.txt', 'file993.txt', 'file89.txt', 'file542.txt', 'file176.txt', 'file452.txt', 'file515.txt', 'file304.txt', 'file410.txt', 'file560.txt', 'file8.txt', 'file36.txt', 'file523.txt', 'file309.txt', 'file187.txt', 'file306.txt', 'file104.txt', 'file121.txt', 'file760.txt', 'file966.txt', 'file349.txt', 'file363.txt', 'file333.txt', 'file656.txt', 'file337.txt', 'file190.txt', 'file347.txt', 'file407.txt', 'file477.txt', 'file276.txt', 'file389.txt', 'file390.txt', 'file206.txt', 'file425.txt', 'file197.txt', 'file139.txt', 'file336.txt', 'file686.txt', 'file423.txt', 'file396.txt', 'file498.txt', 'file404.txt', 'file543.txt', 'file734.txt', 'file362.txt', 'file241.txt', 'file124.txt', 'file789.txt', 'file71.t ...

# %%
import os
import nltk
import string

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def get_all_documents(directory):
    documents = set()
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            documents.add(filename)
    return documents

directory = "text_files_preprocessed"
all_documents = get_all_documents(directory)

# %%
def not_operation(inverted_index, documents, term):
    if term in inverted_index:
        excluded_documents = set(inverted_index[term])
    else:
        excluded_documents = set()
    return list(set(documents) - excluded_documents)

def preprocess_text(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [token for token in tokens if token not in string.punctuation and token not in stop_words]
    tokens = [token for token in tokens if token.strip() != '']
    return tokens

def load_inverted_index(pickle_file):
    with open(pickle_file, 'rb') as file:
        inverted_index = pickle.load(file)
    return inverted_index

def and_operation(inverted_index, documents, term):
    if term not in inverted_index:
        return []
    return list(set(documents) & set(inverted_index[term]))

def or_operation(inverted_index, documents, term):
    if term in inverted_index:
        documents.update(inverted_index[term])
    return list(documents)

def and_not_operation(inverted_index, documents, term):
    if term not in inverted_index:
        return documents
    return list(set(documents) - set(inverted_index[term]))

def or_not_operation(inverted_index, documents, term):
    if term in inverted_index:
        excluded_documents = set(inverted_index[term])
    else:
        excluded_documents = set()
    return list(set(documents) - excluded_documents)


def evaluate_query(inverted_index, query, operations):
    query_terms = query.split()
    if len(query_terms) != len(operations) + 1:
        raise ValueError("Invalid query format")

    # Perform the first operation
    operator = operations[0]
    term1 = query_terms[0]
    term2 = query_terms[1]
    if operator == "AND":
        if term1 not in inverted_index or term2 not in inverted_index:
            result = []
        else:
            result = list(set(inverted_index[term1]) & set(inverted_index[term2]))
    elif operator == "OR":
        documents = set()
        if term1 in inverted_index:
            documents.update(inverted_index[term1])
        if term2 in inverted_index:
            documents.update(inverted_index[term2])
        result = list(documents)
    elif operator == "AND NOT":
        if term1 not in inverted_index or term2 not in inverted_index:
            result = []
        else:
            result = list(set(inverted_index[term1]) & set(not_operation(inverted_index, all_documents, term2)))
    elif operator == "OR NOT":
        if term1 not in inverted_index:
            result = not_operation(inverted_index, all_documents, term2)
        else:
            documents = set(inverted_index[term1])
            documents.update(not_operation(inverted_index, all_documents, term2))
            result = list(documents)
    else:
        raise ValueError("Invalid operator: " + operator)

    # Perform subsequent operations
    for i in range(1, len(operations)):
        operator = operations[i]
        next_term = query_terms[i + 1]
        if operator == "AND":
            result = list(set(result) & set(inverted_index.get(next_term, [])))
        elif operator == "OR":
            documents = set(result)
            if next_term in inverted_index:
                documents.update(inverted_index[next_term])
            result = list(documents)
        elif operator == "AND NOT":
            result = list(set(result) & set(not_operation(inverted_index, all_documents, next_term)))
        elif operator == "OR NOT":
            documents = set(result)
            documents.update(not_operation(inverted_index, all_documents, next_term))
            result = list(documents)
        else:
            raise ValueError("Invalid operator: " + operator)
    
    return result



def preprocess_input(input_sequence):
    preprocessed_sequence = []
    for query in input_sequence:
        preprocessed_query = preprocess_text(query)
        preprocessed_sequence.append(" ".join(preprocessed_query))
    return preprocessed_sequence


if __name__ == "__main__":
    inverted_index = load_inverted_index("inverted_index.pickle")

    N = int(input("Enter the number of queries: "))
    queries = []
    for _ in range(N):
        query = input().strip()
        operations = input().strip().split(", ")
        queries.append((query, operations))

    preprocessed_queries = preprocess_input([query for query, _ in queries])

    for idx, (query, operations) in enumerate(queries):
        query_with_ops = ""
        for token, op in zip(preprocessed_queries[idx].split(), operations):
            query_with_ops += token + " " + op + " "
        query_with_ops += preprocessed_queries[idx].split()[-1]
        result = evaluate_query(inverted_index, preprocessed_queries[idx], operations)
        print(f"Query {idx+1}: {query_with_ops}")
        print(f"Number of documents retrieved for query {idx+1}: {len(result)}")
        print(f"Names of the documents retrieved for query {idx+1}: " + ", ".join([f"{i}" for i in result]))
# Out:
# Query 1: highly AND recommend
# Number of documents retrieved for query 1: 32
# Names of the documents retrieved for query 1: file750.txt, file838.txt, file621.txt, file213.txt, file18.txt, file457.txt, file627.txt, file208.txt, file400.txt, file487.txt, file997.txt, file268.txt, file138.txt, file716.txt, file156.txt, file897.txt, file501.txt, file576.txt, file618.txt, file831.txt, file149.txt, file543.txt, file541.txt, file639.txt, file291.txt, file461.txt, file527.txt, file228.txt, file242.txt, file699.txt, file186.txt, file872.txt
# Query 2: highly OR recommend
# Number of documents retrieved for query 2: 96
# Names of the documents retrieved for query 2: file438.txt, file621.txt, file213.txt, file863.txt, file626.txt, file592.txt, file400.txt, file257.txt, file590.txt, file199.txt, file661.txt, file851.txt, file19.txt, file576.txt, file839.txt, file985.txt, file916.txt, file84.txt, file228.txt, file211.txt, file861.txt, file130.txt, file748.txt, file838.txt, file301.txt, file18.txt, file382.txt, file40.txt, file156.txt, file864.txt, file141.txt, file326.txt, file303.txt, file217.txt, file467.txt, file55.txt, file291.txt, file614.txt, file793.txt, file892.txt, file242.txt, file5.txt, file699.txt, file81.txt, file457.txt, file938.txt, file183.txt, file487.txt, file425.txt, file997.txt, file511.txt, file866.txt, file155.txt, file138.txt, file210.txt, file423.txt, file64.txt, file437.txt, file501.txt, file744.txt, file618.txt, file149.txt, file543.txt, file734.txt, file444.txt, file639.txt, file461.txt, file131.txt, file947.txt, file527.txt, file329.txt, file907.txt, file120.txt, file750.txt, file943.txt, file627.txt, file208.txt, file268.txt, file716.txt, file171.txt, file796.txt, file50.txt, file897.txt, file831.txt, file458.txt, file631.txt, file541.txt, file754.txt, file519.txt, file21.txt, file34.txt, file547.txt, file604.txt, file186.txt, file872.txt, file572.txt
# Query 3: highly AND recommend AND guitar
# Number of documents retrieved for query 3: 11
# Names of the documents retrieved for query 3: file750.txt, file838.txt, file541.txt, file18.txt, file268.txt, file457.txt, file156.txt, file186.txt, file639.txt, file400.txt, file291.txt

# %%
import os
import nltk
import string
import pickle

nltk.download('punkt')
nltk.download('stopwords')

# Function to preprocess text
def preprocess_text(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [token for token in tokens if token not in string.punctuation]
    tokens = [token for token in tokens if token.strip() != '']
    return tokens

# Function to load positional index from file
def load_positional_index(pickle_file):
    with open(pickle_file, 'rb') as file:
        positional_index = pickle.load(file)
    return positional_index

# Function to retrieve documents for phrase query using positional index
def retrieve_documents_for_phrase_query(positional_index, phrase_query):
    terms = preprocess_text(phrase_query)
    if len(terms) == 0:
        return []

    # Initialize result with documents containing the first term
    result = set(positional_index.get(terms[0], {}).keys())

    # Iterate through terms in the phrase query
    for term in terms[1:]:
        if term in positional_index:
            # Get documents containing the current term
            documents_with_term = set(positional_index[term].keys())
            # Find documents common with the current result
            result = result.intersection(documents_with_term)

    # Filter documents where phrase query appears
    for document in list(result):
        positions = [positional_index[term][document] for term in terms]
        if not any(check_sequence(positions, i) for i in range(len(positions[0]))):
            result.remove(document)

    return list(result)

# Function to check if a sequence of positions is consecutive
def check_sequence(positions, index):
    return all(positions[i][0] + index in positions[i+1] for i in range(len(positions)-1))

# Example usage
if __name__ == "__main__":
    # Load positional index
    positional_index = load_positional_index("positional_index.pickle")

    # Input
    N = int(input("Enter the number of queries: "))
    queries = []
    for _ in range(N):
        query = input().strip()
        queries.append(query)

    # Preprocess queries
    preprocessed_queries = [preprocess_text(query) for query in queries]

    # Retrieve documents for each query using positional index
    for idx, query in enumerate(preprocessed_queries):
        result = retrieve_documents_for_phrase_query(positional_index, query)
        print(f"Number of documents retrieved for query {idx+1} using positional index: {len(result)}")
        print(f"Names of documents retrieved for query {idx+1} using positional index: " + ", ".join([f"file{i}.txt" for i in result]))
